# %%
using NamedTrajectories
using QuantumCollocation

# %%
traj = load("../trajectories/g0_to_g1.jld2", "traj");

# %%
ct = ContinuousTrajectory(traj.a, traj.da, get_times(traj));

# %%
fig = plot(ct, LinRange(ct.times[1], ct.times[end], 1000))
fig

# %%
ct([15.2, 2000])
# Out:
# AssertionError: t = 2000.0 must be in the range of the trajectory, i.e. t ∈ [0.0, 989.2055887989388].
#
#
#
# Stacktrace:
#
#  [1] (::ContinuousTrajectory)(t::Float64)
#
#    @ QuantumCollocation.ContinuousTrajectories ~/projects/QuantumCollocation.jl/src/continuous_trajectories.jl:30
#
#  [2] #1
#
#    @ ./none:0 [inlined]
#
#  [3] iterate
#
#    @ ./generator.jl:47 [inlined]
#
#  [4] collect_to!(dest::Vector{Vector{Float64}}, itr::Base.Generator{Vector{Float64}, QuantumCollocation.ContinuousTrajectories.var"#1#2"{ContinuousTrajectory}}, offs::Int64, st::Int64)
#
#    @ Base ./array.jl:845
#
#  [5] collect_to_with_first!(dest::Vector{Vector{Float64}}, v1::Vector{Float64}, itr::Base.Generator{Vector{Float64}, QuantumCollocation.ContinuousTrajectories.var"#1#2"{ContinuousTrajectory}}, st::Int64)
#
#    @ Base ./array.jl:823
#
#  [6] collect(itr::Base.Generator{Vector{Float64}, QuantumCollocation.ContinuousTrajectories.var"#1#2"{ContinuousTrajectory}})
#
#    @ Base ./array.jl:797
#
# ...
